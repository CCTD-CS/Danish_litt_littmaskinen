# %%
with open("DK_denTavskeEnke.txt", "r", encoding="utf-8") as file:
    text = file.read()
    text = text.replace('\f', '')

# %%
# %pip install -q spacy
# %pip install --upgrade pandas
# %pip freeze > requirements.txt
# %pip install --upgrade pandas pandasai
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.12/site-packages (2.3.0)
# Collecting pandasai
#   Downloading pandasai-2.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas) (2023.3)
# Collecting astor<0.9.0,>=0.8.1 (from pandasai)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting duckdb<2.0.0,>=1.0.0 (from pandasai)
#   Downloading duckdb-1.3.0-cp312-cp312-manylinux_2_27_aarch64.manylinux_2_28_aarch64.whl.metadata (7.0 kB)
# Collecting faker<20.0.0,>=19.12.0 (from pandasai)
#   Downloading Faker-19.13.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.3 in /opt/conda/lib/python3.12/site-packages (from pandasai) (3.1.4)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.1 in /opt/conda/lib/python3.12/site-packages (from pandasai) (3.9.2)
# Collecting openai<2 (from pandasai)
#   Downloading openai-1.86.0-py3-none-any.whl.metadata (25 kB)
# Collecting pandas
#   Downloading pandas-1.5.3.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 16.4 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pillow<11.0.0,>=10.1.0 in /opt/conda/lib/python3.12/site-packages (from pandasai) (10.4.0)
# Requirement already satisfied: pydantic<3,>=1 in /opt/conda/lib/python3.12/site-packages (from pandasai) (2.8.2)
# Collecting python-dotenv<2.0.0,>=1.0.0 (from pandasai)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /opt/conda/lib/python3.12/site-packages (from pandasai) (2.32.3)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in /opt/conda/lib/python3.12/site-packages (from pandasai) (1.13.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4 in /opt/conda/lib/python3.12/site-packages (from pandasai) (2.0.34)
# Collecting sqlglot<26.0.0,>=25.0.3 (from sqlglot[rs]<26.0.0,>=25.0.3->pandasai)
#   Downloading sqlglot-25.34.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2<4.0.0,>=3.1.3->pandasai) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (3.1.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/conda/lib/python3.12/site-packages (from openai<2->pandasai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from openai<2->pandasai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.12/site-packages (from openai<2->pandasai) (0.27.0)
# Collecting jiter<1,>=0.4.0 (from openai<2->pandasai)
#   Downloading jiter-0.10.0-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.12/site-packages (from openai<2->pandasai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/conda/lib/python3.12/site-packages (from openai<2->pandasai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /opt/conda/lib/python3.12/site-packages (from openai<2->pandasai) (4.11.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=1->pandasai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=1->pandasai) (2.20.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->pandasai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->pandasai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->pandasai) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->pandasai) (2025.4.26)
# Collecting numpy>=1.21.0 (from pandas)
#   Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (63 kB)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.12/site-packages (from sqlalchemy<3,>=1.4->pandasai) (3.0.1)
# Collecting sqlglotrs==0.3.0 (from sqlglot[rs]<26.0.0,>=25.0.3->pandasai)
#   Downloading sqlglotrs-0.3.0-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (545 bytes)
# Collecting numpy>=1.21.0 (from pandas)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (62 kB)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<2->pandasai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2->pandasai) (0.14.0)
# Downloading pandasai-2.3.0-py3-none-any.whl (185 kB)
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading duckdb-1.3.0-cp312-cp312-manylinux_2_27_aarch64.manylinux_2_28_aarch64.whl (19.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 18.1 MB/s eta 0:00:0000:0100:01
# Downloading Faker-19.13.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 19.0 MB/s eta 0:00:00
# Downloading openai-1.86.0-py3-none-any.whl (730 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 730.3/730.3 kB 16.2 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading sqlglot-25.34.1-py3-none-any.whl (435 kB)
# Downloading sqlglotrs-0.3.0-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (321 kB)
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (13.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 19.5 MB/s eta 0:00:00a 0:00:01
# Downloading jiter-0.10.0-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (345 kB)
# Building wheels for collected packages: pandas
#   Building wheel for pandas (pyproject.toml) ... done
#   Created wheel for pandas: filename=pandas-1.5.3-cp312-cp312-linux_aarch64.whl size=11298446 sha256=203e6c3a570ba2256b56b75ced3943aeaf635db59f98ef571bdc7cd85e684453
#   Stored in directory: /home/vscode/.cache/pip/wheels/fb/83/18/8e7307aa1185c5498c5490e4d9c8a1732d9f1056e86c3491c6
# Successfully built pandas
# Installing collected packages: sqlglotrs, sqlglot, python-dotenv, numpy, jiter, duckdb, astor, pandas, faker, openai, pandasai
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 0.21.0
#     Uninstalling python-dotenv-0.21.0:
#       Successfully uninstalled python-dotenv-0.21.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.0
#     Uninstalling numpy-2.3.0:
#       Successfully uninstalled numpy-2.3.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.3.0
#     Uninstalling pandas-2.3.0:
#       Successfully uninstalled pandas-2.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-expr 1.1.13 requires pandas>=2, but you have pandas 1.5.3 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed astor-0.8.1 duckdb-1.3.0 faker-19.13.0 jiter-0.10.0 numpy-1.26.4 openai-1.86.0 pandas-1.5.3 pandasai-2.3.0 python-dotenv-1.1.0 sqlglot-25.34.1 sqlglotrs-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from spacy.lang.da import Danish
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from spacy.lang.da import Danish
#
# File /opt/conda/lib/python3.12/site-packages/spacy/__init__.py:6
#       3 from typing import Any, Dict, Iterable, Union
#       5 # set library-specific custom warning handling before doing anything else
# ----> 6 from .errors import setup_default_warnings
#       8 setup_default_warnings()  # noqa: E402
#      10 # These are imported as part of the API
#
# File /opt/conda/lib/python3.12/site-packages/spacy/errors.py:3
#       1 import warnings
# ----> 3 from .compat import Literal
#       6 class ErrorsWithCodes(type):
#       7     def __getattribute__(self, code):
#
# File /opt/conda/lib/python3.12/site-packages/spacy/compat.py:4
#       1 """Helpers for Python and platform compatibility."""
#       2 import sys
# ----> 4 from thinc.util import copy_array
#       6 try:
#       7     import cPickle as pickle
#
# File /opt/conda/lib/python3.12/site-packages/thinc/__init__.py:5
#       2 import numpy
#       4 from .about import __version__
# ----> 5 from .config import registry
#       7 # fmt: off
#       8 __all__ = [
#       9     "registry",
#      10     "__version__",
#      11 ]
#
# File /opt/conda/lib/python3.12/site-packages/thinc/config.py:5
#       2 import confection
#       3 from confection import VARIABLE_RE, Config, ConfigValidationError, Promise
# ----> 5 from .types import Decorator
#       8 class registry(confection.registry):
#       9     # fmt: off
#      10     optimizers: Decorator = catalogue.create("thinc", "optimizers", entry_points=True)
#
# File /opt/conda/lib/python3.12/site-packages/thinc/types.py:27
#      24 from pydantic import GetCoreSchemaHandler
#      25 from pydantic_core import core_schema
# ---> 27 from .compat import cupy, has_cupy
#      29 if has_cupy:
#      30     get_array_module = cupy.get_array_module
#
# File /opt/conda/lib/python3.12/site-packages/thinc/compat.py:99
#      95 has_mxnet = False
#      98 try:
# ---> 99     import h5py
#     100 except ImportError:  # pragma: no cover
#     101     h5py = None
#
# File /opt/conda/lib/python3.12/site-packages/h5py/__init__.py:45
#      36     _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
#      37            "this may cause problems").format(
#      38             '{0}.{1}.{2}'.format(*version.hdf5_version_tuple),
#      39             '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)
#      40     ))
#      43 _errors.silence_errors()
# ---> 45 from ._conv import register_converters as _register_converters, \
#      46                    unregister_converters as _unregister_converters
#      47 _register_converters()
#      48 atexit.register(_unregister_converters)
#
# File h5py/_conv.pyx:1, in init h5py._conv()
#
# File h5py/h5r.pyx:1, in init h5py.h5r()
#
# File h5py/h5p.pyx:1, in init h5py.h5p()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
import numpy as np
import pandas as pd
print(f"NumPy version: {np.__version__}")
print(f"Pandas version: {pd.__version__}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 import numpy as np
# ----> 2 import pandas as pd
#       3 print(f"NumPy version: {np.__version__}")
#       4 print(f"Pandas version: {pd.__version__}")
#
# File /opt/conda/lib/python3.12/site-packages/pandas/__init__.py:22
#      19 del _hard_dependencies, _dependency, _missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File /opt/conda/lib/python3.12/site-packages/pandas/compat/__init__.py:17
#      14 import sys
#      15 from typing import TYPE_CHECKING
# ---> 17 from pandas._typing import F
#      18 from pandas.compat.numpy import (
#      19     is_numpy_dev,
#      20     np_version_under1p21,
#      21 )
#      22 from pandas.compat.pyarrow import (
#      23     pa_version_under1p01,
#      24     pa_version_under2p0,
#    (...)
#      31     pa_version_under9p0,
#      32 )
#
# File /opt/conda/lib/python3.12/site-packages/pandas/_typing.py:132
#     126 Frequency = Union[str, "BaseOffset"]
#     127 Axes = Union[AnyArrayLike, List, range]
#     129 RandomState = Union[
#     130     int,
#     131     ArrayLike,
# --> 132     np.random.Generator,
#     133     np.random.BitGenerator,
#     134     np.random.RandomState,
#     135 ]
#     137 # dtypes
#     138 NpDtype = Union[str, np.dtype, type_t[Union[str, complex, bool, object]]]
#
# File /opt/conda/lib/python3.12/site-packages/numpy/__init__.py:721, in __getattr__(attr)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File /opt/conda/lib/python3.12/site-packages/numpy/random/__init__.py:180
#     126 __all__ = [
#     127     'beta',
#     128     'binomial',
#    (...)
#     176     'zipf',
#     177 ]
#     179 # add these for module-freeze analysis (like PyInstaller)
# --> 180 from . import _pickle
#     181 from . import _common
#     182 from . import _bounded_integers
#
# File /opt/conda/lib/python3.12/site-packages/numpy/random/_pickle.py:1
# ----> 1 from .mtrand import RandomState
#       2 from ._philox import Philox
#       3 from ._pcg64 import PCG64, PCG64DXSM
#
# File numpy/random/mtrand.pyx:1, in init numpy.random.mtrand()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject
